# %%
mbtaURL = "https://api-v3.mbta.com/vehicles?filter[route]=1&include=trip"

import urllib.request, json
with urllib.request.urlopen(mbtaURL) as url:
    data = json.loads(url.read().decode())
   
    with open('data.json', 'w') as outfile:
        json.dump(data, outfile)
   
    with open('data.txt', 'w') as outfile:
        json.dump(json.dumps(data, indent=4, sort_keys=True), outfile)
       
    print(json.dumps(data, indent=4, sort_keys=True))
# Out:
# {
#     "data": [
#         {
#             "attributes": {
#                 "bearing": 0,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 2,
#                 "direction_id": 1,
#                 "label": "1914",
#                 "latitude": 42.37117155,
#                 "longitude": -71.1163031,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-05-27T06:37:33-04:00"
#             },
#             "id": "y1914",
#             "links": {
#                 "self": "/vehicles/y1914"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "66",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "51092398",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 324,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 9,
#                 "direction_id": 0,
#                 "label": "1899",
#                 "latitude": 42.3391993,
#                 "longitude": -71.08017684,
#                 "occupancy_status": "FEW_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-05-27T06:37:36-04:00"
#             },
#             "id": "y1899",
#             "links": {
#                 "self": "/vehicles/y1899"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "87",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "51092450",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 0,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 6,
#                 "direction_id": 0,
#                 "label": "1896",
#                 "latitude": 42.33385018,
#                 "longitude": -71.07371475,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-05-27T06:37:35-04:00"
#             },
#             "id": "y1896",
#             "links": {
#                 "self": "/vehicles/y1896"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "57",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "51092482",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 0,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 1,
#                 "direction_id": 0,
#                 "label": "1811",
#                 "latitude": 42.33663079,
#                 "longitude": -71.07692928,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-05-27T06:37:08-04:00"
#             },
#             "id": "y1811",
#             "links": {
#                 "self": "/vehicles/y1811"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "64",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "51092513",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 315,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 22,
#                 "direction_id": 1,
#                 "label": "1803",
#                 "latitude": 42.33258,
#                 "longitude": -71.08042,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-05-27T06:36:56-04:00"
#             },
#             "id": "y1803",
#             "links": {
#                 "self": "/vehicles/y1803"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "62",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "51092381",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 0,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 1,
#                 "direction_id": 0,
#                 "label": "1755",
#                 "latitude": 42.37306882,
#                 "longitude": -71.11760896,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-05-27T06:37:25-04:00"
#             },
#             "id": "y1755",
#             "links": {
#                 "self": "/vehicles/y1755"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "110",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "51092423",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         },
#         {
#             "attributes": {
#                 "bearing": 126,
#                 "current_status": "IN_TRANSIT_TO",
#                 "current_stop_sequence": 14,
#                 "direction_id": 1,
#                 "label": "1740",
#                 "latitude": 42.343065269,
#                 "longitude": -71.08530693,
#                 "occupancy_status": "MANY_SEATS_AVAILABLE",
#                 "speed": null,
#                 "updated_at": "2022-05-27T06:37:36-04:00"
#             },
#             "id": "y1740",
#             "links": {
#                 "self": "/vehicles/y1740"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "stop": {
#                     "data": {
#                         "id": "82",
#                         "type": "stop"
#                     }
#                 },
#                 "trip": {
#                     "data": {
#                         "id": "51092387",
#                         "type": "trip"
#                     }
#                 }
#             },
#             "type": "vehicle"
#         }
#     ],
#     "included": [
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-6",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "51092381",
#             "links": {
#                 "self": "/trips/51092381"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "SpringWeekday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010109",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-9",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "51092387",
#             "links": {
#                 "self": "/trips/51092387"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "SpringWeekday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010109",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-1",
#                 "direction_id": 1,
#                 "headsign": "Nubian",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "51092398",
#             "links": {
#                 "self": "/trips/51092398"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-1",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "SpringWeekday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010109",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-13",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "51092423",
#             "links": {
#                 "self": "/trips/51092423"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "SpringWeekday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010108",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-2",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "51092450",
#             "links": {
#                 "self": "/trips/51092450"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "SpringWeekday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010108",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-3",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "51092482",
#             "links": {
#                 "self": "/trips/51092482"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "SpringWeekday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010108",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         },
#         {
#             "attributes": {
#                 "bikes_allowed": 1,
#                 "block_id": "C01-4",
#                 "direction_id": 0,
#                 "headsign": "Harvard",
#                 "name": "",
#                 "wheelchair_accessible": 1
#             },
#             "id": "51092513",
#             "links": {
#                 "self": "/trips/51092513"
#             },
#             "relationships": {
#                 "route": {
#                     "data": {
#                         "id": "1",
#                         "type": "route"
#                     }
#                 },
#                 "route_pattern": {
#                     "data": {
#                         "id": "1-_-0",
#                         "type": "route_pattern"
#                     }
#                 },
#                 "service": {
#                     "data": {
#                         "id": "SpringWeekday",
#                         "type": "service"
#                     }
#                 },
#                 "shape": {
#                     "data": {
#                         "id": "010108",
#                         "type": "shape"
#                     }
#                 }
#             },
#             "type": "trip"
#         }
#     ],
#     "jsonapi": {
#         "version": "1.0"
#     }
# }

# %%
import sys
print(sys.exc_info())
# Out:
# (None, None, None)
